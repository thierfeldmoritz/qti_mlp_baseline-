# %% [markdown]
# Performance Evaluation for QTI(+) fit/regression/MLP prediction results.
# Paths:

# %%
#-------------------------------------------------------------------------------------
# paths sub_naive_min_3/dps3
out_dir='Performance_eval_sub_naive_min_3_'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_naive_min_pp_3/dps3
out_dir='Performance_eval_sub_naive_min_3_pp_11P5_dbl_clmpd'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_naive_min_3_pp_pipe_2/dps3_fit_nan_clmpd.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP ENSEMBLE_Prot_Vgl_sub_min_opt_pp:
out_dir='P_eval_ENSEMBLE_Prot_Vgl_sub_min_opt_pp'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P1/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P1_vs_P10P2P11_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P10/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P10_vs_P2P11P3_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P2/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P2_vs_P11P3P12_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P11/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P3/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P3_vs_P12P4P13_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P12/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P12_vs_P4P13P5_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P4/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P4_vs_P13P5P14_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P13/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P13_vs_P5P14P6_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P5/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P5_vs_P14P6P15_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P14/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P14_vs_P6P15P7_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P6/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P6_vs_P15P7P16_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P15/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P15_vs_P7P16P8_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P7/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P7_vs_P16P8P17_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P16/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P16_vs_P8P17P9_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P8/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P8_vs_P17P9P18_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P17/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P17_vs_P9P18P1_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P9/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P9_vs_P18P1P10_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_opt_pp/P18/QTI_MLP_14P_Prot_Vgl_sub_min_opt_pp_ens_f18_ts_P18_vs_P1P10P2_20231016_00h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_min_pp/dps3
out_dir='Performance_eval_QTIp_sub_min_opt_pp_dbl_clmpd'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_opt_pp_pipe_2/dps3_nan_clmpd.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP high res SNR test:
out_dir='P_eval_high_res_SNR_ref_fit'
# pred_path = ['/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test/SNR/bm/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat']
# pred_path = ['/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test/SNR/simulation/2_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat']
# pred_path = ['/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test/SNR/simulation/2_0/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat']
# pred_path = ['/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test/SNR/simulation/1_8/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat']
# pred_path = ['/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test/SNR/simulation/1_6/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat']
# pred_path = ['/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test/SNR/simulation/1_4/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat']
# pred_path = ['/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test/SNR/simulation/1_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat']

pred_path = ['/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat']

target_path = ['/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat']
mask_path = ['/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz']

# %%
#-------------------------------------------------------------------------------------
# paths sub_min/dps3 = "THE SHORT PROTOCOL"
out_dir='P_eval_fit_sub_min_unclamped'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pipe_2/dps3.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_min/dps3 b0_incl = "THE SHORT PROTOCOL" w/ b0 in fit (no clamping)
out_dir='P_eval_fit_sub_min_b0_incl'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pipe_2_b0_incl/dps3_.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pipe_2_b0_incl/dps3.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_min/dps3 = "THE SHORT PROTOCOL" w/ b0 in fit clmpd
out_dir='P_eval_fit_sub_min'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_min/dps3 b0_incl = "THE SHORT PROTOCOL" w/ b0 in fit (fit_nan_clmpd), GT fit_nan_clmpd
out_dir='P_eval_fit_sub_min_b0_incl'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_fit_nan_clmpd.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_min/dps3 = "THE SHORT PROTOCOL",  (fit_nan_clmpd), GT doubleclamped
out_dir='P_eval_fit_sub_min_common_clamp'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_min/dps3 b0_incl = "THE SHORT PROTOCOL" w/ b0 in fit (fit_nan_clmpd), GT double clmpd
out_dir='P_eval_fit_sub_min_b0_incl_common_clamp'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pipe_2_b0_incl/dps3_fit_nan_clmpd.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
out_dir='P_eval_fit_cmp_sub_min_pp_pipe_2_b0_incl'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pp_pipe_2_b0_incl/dps3_fit_cmp_nan_clmpd.mat',\
            ]
target_path = [\
        '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_fit_cmp_nan_clmpd.mat',\
        ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths ABSTRACT BM MLP 2.5 mm sub min:
out_dir='P_eval_BENCHMARK_ABSTRACT_sub_min'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P1/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P1_vs_P10_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P10/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P10_vs_P2_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P2/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P2_vs_P11_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P11/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P11_vs_P3_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P3/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P3_vs_P12_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P12/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P12_vs_P4_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P4/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P4_vs_P13_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P13/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P13_vs_P5_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P5/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P5_vs_P14_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P14/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P14_vs_P6_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P6/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P6_vs_P15_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P15/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P15_vs_P7_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P7/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P7_vs_P16_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P16/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P16_vs_P8_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P8/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P8_vs_P17_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P17/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P17_vs_P9_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P9/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P9_vs_P18_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P18/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
#  ABSTRACT HIGH RES DIFF MAPS
out_dir='ABSTRACT_High_Res_MLP_sub_min'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_ABSTRACT/sub/full/FINAL/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P20/full/qtip_high_res_pipe_2/dps3.mat'
             ]
# mask_path = [\
#              '/Volumes/Maxtor/ML_TS/P20/full/manual_mask.nii.gz'
#              ]
# pred_path = [\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2/dps3.mat' #_fit_nan_clmpd
#             ]
# target_path = [\
#              '/Volumes/Maxtor/ML_TS/P20/full/qtip_high_res_pipe_2/dps3_fit_nan_clmpd.mat'
#              ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P20/full/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# THESIS HIGH RES DIFF MAPS
# for the statistics: GT: _nan_clmpd_clmpd, MLP: no clamp, fit: fit_nan_clmpd
# for the maps: no clamping anywhere!
out_dir='THESIS_High_Res_MLP_sub_min'
# MLP:
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_ABSTRACT/sub/full/FINAL/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P20/full/qtip_high_res_pipe_2/dps3_nan_clmpd_clmpd.mat' #
             ]

# fit:
# pred_path = [\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2/dps3_fit_nan_clmpd.mat' 
#             ]
# target_path = [\
#              '/Volumes/Maxtor/ML_TS/P20/full/qtip_high_res_pipe_2/dps3_nan_clmpd_clmpd.mat'
#              ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P20/full/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# THESIS HIGH RES DIFF MAPS
# maybe clamp the target:
# for the statistics: GT: _nan_clmpd_clmpd, MLP: no clamp, fit: fit_nan_clmpd
# for the maps: no clamping anywhere!
out_dir='Peval_GIRF4dMRI_acc_grad_test'

pred_path = [\
            '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2_b0_incl_acc_grad/dps3.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2_b0_incl/dps3.mat' #
             ]

mask_path = [\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz'
             ]

# %% [markdown]
# Imports:

# %%
from Eval_metrics import QTI_Fit_Dataset
import matplotlib.pyplot as plt
# # plotting (open interactive plots):
# %matplotlib qt # open in extra window
# %matplotlib widget # open in notebook

# %% [markdown]
# Slice exclusion index pairs for all 18P:

# %%
# slice_ind = [[2, 23], [0, 23], [0, 22], [0, 23], [0, 23], [1, 23], [1, 23],\
#               [0, 22], [0, 23], [0, 23], [0, 22], [0, 22],\
#                 [0, 23], [1, 22], [0, 22], [1, 23], [0, 22], [0, 23]] # 0:

slice_ind = [[2, 21] for _ in range(len(pred_path))]

# %%
#-------------------------------------------------------------------------------------
# create QTI_Fit_Dataset instance:
ds_eval = QTI_Fit_Dataset(pred_path, target_path, mask_path, out_path='/Users/olivergoedicke/Documents/Uni/PhD/Results/IR_QTI/Protocol_cmp_b0_incl', out_dir=out_dir,\
             invar_keys = ['MD', 'FA', 'uFA', 'C_c', 'C_MD'], slice_ind=slice_ind) #'s0', 'MD', 'FA', 'uFA', 'C_c'

# %%
#-------------------------------------------------------------------------------------
# perform preparations:
ds_eval.expand_mask()
ds_eval.mask_nan_vals()
ds_eval.mask_zero_vals()
# ds_eval.mask_near_zero_vals(eps=1e-2)

# %%
ds_eval.compute_SSIM(kernel_size=5)
ds_eval.SSIM_boxplot()
# ds_eval.save_SSIM()

# %%
#-------------------------------------------------------------------------------------
# perform calculations (brain-wise):
ds_eval.compute_abs_diff()
ds_eval.compute_rel_diff()

ds_eval.compute_nRMSE()
ds_eval.compute_pSNR()
ds_eval.save_nRMSE()
ds_eval.save_pSNR()

# %%
ds_eval.SSIM_boxplot()

# %%
#-------------------------------------------------------------------------------------
# plotting (open interactive plots):
# %matplotlib qt
# %matplotlib widget
fig1, ax1 = ds_eval.nRMSE_boxplot(save=True, out_dir='nRMSE_plots', annotate=True)
fig2, ax2 = ds_eval.pSNR_boxplot(save=False, out_dir='nRMSE_plots', annotate=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#-------------------------------------------------------------------------------------
# (slice-wise):
ds_eval.set_brain_wise(False)
ds_eval.set_slice_wise(True)
ds_eval.compute_nRMSE()
ds_eval.compute_pSNR()
ds_eval.save_nRMSE()
ds_eval.save_pSNR()

# %%
#-------------------------------------------------------------------------------------
# plotting (open interactive plots):
# %matplotlib qt
# %matplotlib widget
fig3, ax3 = ds_eval.nRMSE_boxplot(save=True, out_dir='nRMSE_plots', annotate=True)
fig4, ax4 = ds_eval.pSNR_boxplot(save=True, out_dir='nRMSE_plots', annotate=True)

# %%
#-------------------------------------------------------------------------------------
# (all voxel-wise):
ds_eval.compute_abs_diff()
ds_eval.compute_rel_diff()
ds_eval.set_slice_wise(False)
ds_eval.compute_nRMSE()
ds_eval.compute_pSNR()
ds_eval.save_nRMSE()
ds_eval.save_pSNR()

# %%
#-------------------------------------------------------------------------------------
# plotting (open interactive plots):
# %matplotlib qt
# %matplotlib widget
fig5, ax5 = ds_eval.nRMSE_boxplot(save=True, out_dir='nRMSE_plots', annotate=True)
fig6, ax6 = ds_eval.pSNR_boxplot(save=True, out_dir='nRMSE_plots', annotate=True)

# %%
#-------------------------------------------------------------------------------------
# plotting:
# toggle options: diff = 'rel', 'abs' (default = '' for diff)
# %matplotlib qt
import cmasher as cmr
# cmap = cmr.dusk
# cmap = cmr.get_sub_cmap('cmr.torch', 0.0, .8)
# cmr.import_cmaps('/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Code/cmaps/cm_og_7.jscm')
# cmap = cmr.cm.og_7
cmap = cmr.iceburn 
# %matplotlib widget
figs, axs, sldrs_file, sldrs_slice = ds_eval.plot_diff(diff='abs', slice_ind=7, file_ind=0, save=True, out_dir='Diff_plots', cmap='inferno', vmin=0.0, vmax=0.05)#)

# %%
#-------------------------------------------------------------------------------------
# plotting:
# toggle options: diff = 'rel', 'abs' (default = '' for diff), diff = y_target - y_pred
import cmasher as cmr
cmap = cmr.iceburn  # redshift iceburn
# cmap = cmr.get_sub_cmap('cmr.redshift', .1, .9)
figs2, axs2, sldrs_file2, sldrs_slice2 = ds_eval.plot_diff(diff='', slice_ind=7, file_ind=0, save=True, out_dir='Diff_maps', cmap=cmap, vmin=-0.3, vmax=0.3)#)

# %%
#-------------------------------------------------------------------------------------
# saving:
# ds_eval.save_diff_2_mat(out_dir='Diff', diff='abs', sep_files=True, sep_invars=False)
# ds_eval.save_diff_2_nii(diff='abs', out_dir='Diff_nii')
# ds_eval.save_nRMSE(out_dir='nRMSE')
# ds_eval.save_pSNR(out_dir='nRMSE')

# %%
import cmasher as cmr
cmr.import_cmaps('/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Code/cmaps/cm_og_1.jscm')
cmap = cmr.cm.og_1

# %%
import matplotlib.colors
print(matplotlib.colors.to_rgba('deepskyblue', alpha=None))

# %%
import matplotlib.colors
# (0.27450980392156865, 0.5098039215686274, 0.7058823529411765) % steelblue
# (0.4, 0.803921568627451, 0.6666666666666666) % mediumaquamarine
# (0.803921568627451, 0.3607843137254902, 0.3607843137254902) % indianred
print(matplotlib.colors.to_hex((0.4, 0.803921568627451, 0.6666666666666666)))

# %%
import cmasher as cmr
import numpy as np 
import matplotlib.pyplot as plt

# %matplotlib widget
plt.style.use('dark_background')

cmap = cmr.iceburn
data = np.random.randn(88, 88) 

fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
line = ax.imshow(data, cmap = cmap, vmax = .3 , vmin = -.3)
ax.axis('off')
fig.colorbar(line)

plt.savefig('/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Dokumentation/Abteilungsseminar/Methods/cbar' + '.pdf',\
    format='pdf', dpi=1200, bbox_inches='tight') # , transparent=True, pad_inches=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# Hypothetical FID data generation
time = np.linspace(0, 2.5, 1000)  # Time in milliseconds
decay_constant = 0.5
frequency = 5
amplitude = 1
noise_level = 0.02

# FID signal formula: A * exp(-t/T2) * cos(2*pi*f*t) + noise
fid_signal = amplitude * np.exp(-time/decay_constant) * np.cos(2 * np.pi * frequency * time)
# fid_signal += np.random.normal(0, noise_level, time.shape)

# Plotting the FID signal
plt.figure(figsize=(10, 10))
plt.plot(time, fid_signal, label='FID Signal', color='steelblue', linewidth=5 )
# plt.title('Free Induction Decay (FID)')
# plt.xlabel('Time (ms)')
# plt.ylabel('Signal Amplitude')
# plt.legend()
# plt.grid(True)
# Plotting the FID signal
# plt.title('Free Induction Decay (FID)')
plt.axis('off')  # Turn off the axes
plt.box(False)  # Turn off the box
plt.show()
