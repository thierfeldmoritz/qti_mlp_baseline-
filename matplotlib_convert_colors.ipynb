# %%
import cmasher as cmr
cmr.import_cmaps('/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Code/cmaps/cm_og_1.jscm')
cmap = cmr.cm.og_1

# %%
import matplotlib.colors
print(matplotlib.colors.to_rgba('steelblue', alpha=None))
print(matplotlib.colors.to_rgba('mediumaquamarine', alpha=None))
print(matplotlib.colors.to_rgba('indianred', alpha=None))
# Out:
# (0.27450980392156865, 0.5098039215686274, 0.7058823529411765, 1.0)
# (0.4, 0.803921568627451, 0.6666666666666666, 1.0)
# (0.803921568627451, 0.3607843137254902, 0.3607843137254902, 1.0)

# %%
import matplotlib.colors
# (0.27450980392156865, 0.5098039215686274, 0.7058823529411765) % steelblue
# (0.4, 0.803921568627451, 0.6666666666666666) % mediumaquamarine
# (0.803921568627451, 0.3607843137254902, 0.3607843137254902) % indianred
print(matplotlib.colors.to_hex((0.27450980392156865, 0.5098039215686274, 0.7058823529411765)))
print(matplotlib.colors.to_hex((0.4, 0.803921568627451, 0.6666666666666666)))
print(matplotlib.colors.to_hex((0.803921568627451, 0.3607843137254902, 0.3607843137254902)))
# Out:
# #4682b4
# #66cdaa
# #cd5c5c
