# %% [markdown]
# Performance Evaluation for QTI(+) fit/regression/MLP prediction results.
# Paths:

# %%
#-------------------------------------------------------------------------------------
# paths sub_min/dps3
out_dir='Performance_eval_sub_min_no_eps_fix'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pipe_2/dps3.mat',\
            ]
target_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3.mat',\
            ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_naive_min_3/dps3
out_dir='Performance_eval_sub_naive_min_3_no_eps_fix'
pred_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_naive_min_3_pipe_2/dps3.mat',\
            ]
target_path = [\
            '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3.mat',\
            ]
mask_path = [\
            '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_naive_min_pp_3/dps3
out_dir='Performance_eval_sub_min_pp_5P'
pred_path = [\
            # '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pp_pipe_2/dps3.mat',\
            ]
target_path = [\
            # '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3.mat',\
            ]
mask_path = [\
            # '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]

# %%
#-------------------------------------------------------------------------------------
# paths sub_naive_min_3_pp/dps3
'''
out_dir='Performance_eval_sub_min_pp_5P'
pred_path = [\
            # '/Volumes/Maxtor/ML_TS/P1/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P17/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P3/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P5/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P6/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P8/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P9/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P10/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P12/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P13/qtip_sub_min_pp_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P14/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_sub_min_pp_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_sub_min_pp_pipe_2/dps3.mat',\
            ]
target_path = [\
            # '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3.mat',\
            # '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3.mat',\
            '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3.mat',\
            ]
mask_path = [\
            # '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
            # '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz',\
            '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
            ]
            '''

# %%
#-------------------------------------------------------------------------------------
# paths MLP ENSEMBLE_Prot_Vgl_sub_alt_pp:
out_dir='P_eval_ENSEMBLE_Prot_Vgl_sub_alt_pp'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P1/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P1_vs_P10P2P11_20231016_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P10/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P10_vs_P2P11P3_20231016_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P2/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P2_vs_P11P3P12_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P11/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P11_vs_P3P12P4_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P3/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P3_vs_P12P4P13_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P12/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P12_vs_P4P13P5_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P4/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P4_vs_P13P5P14_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P13/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P13_vs_P5P14P6_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P5/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P5_vs_P14P6P15_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P14/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P14_vs_P6P15P7_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P6/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P6_vs_P15P7P16_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P15/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P15_vs_P7P16P8_20231016_18h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P7/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P7_vs_P16P8P17_20231016_19h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P16/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P16_vs_P8P17P9_20231016_19h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P8/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P8_vs_P17P9P18_20231016_19h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P17/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P17_vs_P9P18P1_20231016_19h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P9/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P9_vs_P18P1P10_20231016_19h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_pp/P18/QTI_MLP_14P_Prot_Vgl_sub_alt_pp_ens_f18_ts_P18_vs_P1P10P2_20231016_19h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP ENSEMBLE_Prot_Vgl_sub_alt_opt_pp:
out_dir='P_eval_ENSEMBLE_Prot_Vgl_sub_alt_opt_pp'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P1/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P1_vs_P10P2P11_20231016_15h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P10/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P10_vs_P2P11P3_20231016_15h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P2/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P2_vs_P11P3P12_20231016_15h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P11/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P11_vs_P3P12P4_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P3/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P3_vs_P12P4P13_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P12/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P12_vs_P4P13P5_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P4/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P4_vs_P13P5P14_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P13/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P13_vs_P5P14P6_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P5/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P5_vs_P14P6P15_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P14/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P14_vs_P6P15P7_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P6/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P6_vs_P15P7P16_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P15/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P15_vs_P7P16P8_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P7/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P7_vs_P16P8P17_20231016_16h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P16/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P16_vs_P8P17P9_20231016_17h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P8/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P8_vs_P17P9P18_20231016_17h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P17/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P17_vs_P9P18P1_20231016_17h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P9/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P9_vs_P18P1P10_20231016_17h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_alt_opt_pp/P18/QTI_MLP_14P_Prot_Vgl_sub_alt_opt_pp_ens_f18_ts_P18_vs_P1P10P2_20231016_17h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP ENSEMBLE_Prot_Vgl_sub_min_pp:
out_dir='P_eval_ENSEMBLE_Prot_Vgl_sub_min_pp'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P1/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P1_vs_P10P2P11_20231016_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P10/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P10_vs_P2P11P3_20231016_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P2_vs_P11P3P12_20231016_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231016_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P3/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P3_vs_P12P4P13_20231016_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P12/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P12_vs_P4P13P5_20231016_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P4/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P4_vs_P13P5P14_20231016_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P13/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P13_vs_P5P14P6_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P5/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P5_vs_P14P6P15_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P14/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P14_vs_P6P15P7_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P6/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P6_vs_P15P7P16_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P15/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P15_vs_P7P16P8_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P7/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P7_vs_P16P8P17_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P16/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P16_vs_P8P17P9_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P8/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P8_vs_P17P9P18_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P17/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P17_vs_P9P18P1_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P9/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P9_vs_P18P1P10_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P18/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P18_vs_P1P10P2_20231016_11h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP ENSEMBLE_Prot_Vgl_sub_min_pp:
out_dir='P_eval_ENSEMBLE_f3_Prot_Vgl_sub_min_pp'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P1/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P1P10P2P11P3P12_vs_P4P13_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P10/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P1P10P2P11P3P12_vs_P4P13_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P1P10P2P11P3P12_vs_P4P13_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P1P10P2P11P3P12_vs_P4P13_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P3/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P1P10P2P11P3P12_vs_P4P13_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P12/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P1P10P2P11P3P12_vs_P4P13_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P4/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P4P13P5P14P6P15_vs_P7P16_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P13/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P4P13P5P14P6P15_vs_P7P16_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P5/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P4P13P5P14P6P15_vs_P7P16_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P14/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P4P13P5P14P6P15_vs_P7P16_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P6/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P4P13P5P14P6P15_vs_P7P16_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P15/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P4P13P5P14P6P15_vs_P7P16_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P7/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P7P16P8P17P9P18_vs_P1P10_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P16/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P7P16P8P17P9P18_vs_P1P10_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P8/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P7P16P8P17P9P18_vs_P1P10_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P17/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P7P16P8P17P9P18_vs_P1P10_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P9/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P7P16P8P17P9P18_vs_P1P10_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P18/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f3_ts_P7P16P8P17P9P18_vs_P1P10_20231017_21h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP ENSEMBLE_Prot_Vgl_sub_min_pp:
out_dir='P_eval_ENSEMBLE_f6_Prot_Vgl_sub_min_pp'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P1/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P1P10P2_vs_P11P3_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P10/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P1P10P2_vs_P11P3_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P1P10P2_vs_P11P3_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P11P3P12_vs_P4P13_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P3/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P11P3P12_vs_P4P13_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P12/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P11P3P12_vs_P4P13_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P4/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P4P13P5_vs_P14P6_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P13/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P4P13P5_vs_P14P6_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P5/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P4P13P5_vs_P14P6_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P14/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P14P6P15_vs_P7P16_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P6/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P14P6P15_vs_P7P16_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P15/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P14P6P15_vs_P7P16_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P7/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P7P16P8_vs_P17P9_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P16/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P7P16P8_vs_P17P9_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P8/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P7P16P8_vs_P17P9_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P17/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P17P9P18_vs_P1P10_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P9/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P17P9P18_vs_P1P10_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_min_pp/P18/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f6_ts_P17P9P18_vs_P1P10_20231018_09h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP ENSEMBLE_Prot_Vgl_sub_min_pp:
out_dir='case_n'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Prelim_bm_scheduler/P1/QTI_MLP_14P_Prelim_bm_sched_exp_sub_min_pp_case_n_ens_f1_ts_P1P10P2_vs_P11P3_20231023_16h_ep150_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Prelim_bm_scheduler/P10/QTI_MLP_14P_Prelim_bm_sched_exp_sub_min_pp_case_n_ens_f1_ts_P1P10P2_vs_P11P3_20231023_16h_ep150_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Prelim_bm_scheduler/P2/QTI_MLP_14P_Prelim_bm_sched_exp_sub_min_pp_case_n_ens_f1_ts_P1P10P2_vs_P11P3_20231023_16h_ep150_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths ABSTRACT BM MLP 2.5 mm sub min:
out_dir='P_eval_BENCHMARK_ABSTRACT_sub_min'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P1/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P1_vs_P10_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P10/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P10_vs_P2_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P2/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P2_vs_P11_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P11/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P11_vs_P3_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P3/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P3_vs_P12_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P12/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P12_vs_P4_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P4/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P4_vs_P13_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P13/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P13_vs_P5_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P5/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P5_vs_P14_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P14/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P14_vs_P6_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P6/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P6_vs_P15_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P15/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P15_vs_P7_20231029_13h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P7/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P7_vs_P16_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P16/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P16_vs_P8_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P8/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P8_vs_P17_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P17/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P17_vs_P9_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P9/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P9_vs_P18_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P18/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP ENSEMBLE_Prot_Vgl_sub_min_pp:
out_dir='P_eval_BENCHMARK_ABSTRACT_sub_min_all_in'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P1/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P1_20231031_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P10/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P10_20231031_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P2/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P2_20231031_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P11/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P11_20231031_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P3/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P3_20231031_14h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P12/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P12_20231031_15h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P4/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P4_20231031_15h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P13/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P13_20231031_15h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P5/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P5_20231031_15h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P14/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P14_20231031_15h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P6/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P6_20231031_15h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P15/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P15_20231031_16h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P7/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P7_20231031_16h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P16/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P16_20231031_16h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P8/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P8_20231031_16h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P17/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P17_20231031_16h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P9/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P9_20231031_16h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/all_in/P18/QTI_MLP_17P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts__vs_P18_20231031_17h_ep100_LR1e-03_bs512_outnorm_sched_92_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp: f=6
out_dir='P_eval_ENSEMBLE_f6_Prot_Vgl_sub_naive_min_3_pp'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P1/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P1P10P2_vs_P11P3_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P10/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P1P10P2_vs_P11P3_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P2/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P1P10P2_vs_P11P3_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P11/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P11P3P12_vs_P4P13_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P3/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P11P3P12_vs_P4P13_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P12/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P11P3P12_vs_P4P13_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P4/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P4P13P5_vs_P14P6_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P13/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P4P13P5_vs_P14P6_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P5/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P4P13P5_vs_P14P6_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P14/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P14P6P15_vs_P7P16_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P6/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P14P6P15_vs_P7P16_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P15/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P14P6P15_vs_P7P16_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P7/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P7P16P8_vs_P17P9_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P16/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P7P16P8_vs_P17P9_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P8/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P7P16P8_vs_P17P9_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P17/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P17P9P18_vs_P1P10_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P9/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P17P9P18_vs_P1P10_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/ENSEMBLE_Prot_Vgl_sub_naive_min_3_pp/P18/QTI_MLP_13P_ens_f_sub_naive_min_3_ens_f6_ts_P17P9P18_vs_P1P10_20240112_12h_ep50_LR1e-04_bs512_outnorm_dps_pred.mat'
            ]
target_path = [\
             '/Volumes/Maxtor/ML_TS/P1/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P10/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P11/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P3/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P12/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P4/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P13/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P5/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P14/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P6/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P15/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P7/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P16/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P8/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P17/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P9/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat',\
             '/Volumes/Maxtor/ML_TS/P18/qtip_full_pipe_2/dps3_nan_clmpd_clmpd.mat'
             ]
mask_path = [\
             '/Volumes/Maxtor/ML_TS/P1/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P10/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P2/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P11/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P3/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P12/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P4/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P13/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P5/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P14/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P6/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P15/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P7/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P16/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P8/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P17/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P9/manual_mask.nii.gz',\
             '/Volumes/Maxtor/ML_TS/P18/manual_mask.nii.gz'
             ]

# %%
#-------------------------------------------------------------------------------------
# paths MLP Paper_Base_Run f=18, b=0 incl., XYZ, real
out_dir='Paper_Base_Run_f18_sub_min'
pred_path = [\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P1/QTI_MLP_16P_sub_min_ens_f18_ts_P1_vs_P10_20241203_13h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P10/QTI_MLP_16P_sub_min_ens_f18_ts_P10_vs_P2_20241203_13h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P2/QTI_MLP_16P_sub_min_ens_f18_ts_P2_vs_P11_20241203_14h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P11/QTI_MLP_16P_sub_min_ens_f18_ts_P11_vs_P3_20241203_14h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P3/QTI_MLP_16P_sub_min_ens_f18_ts_P3_vs_P12_20241203_14h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P12/QTI_MLP_16P_sub_min_ens_f18_ts_P12_vs_P4_20241203_14h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P4/QTI_MLP_16P_sub_min_ens_f18_ts_P13_vs_P5_20241203_14h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P13/QTI_MLP_16P_sub_min_ens_f18_ts_P5_vs_P14_20241203_14h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P5/QTI_MLP_16P_sub_min_ens_f18_ts_P4_vs_P13_20241203_14h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P14/QTI_MLP_16P_sub_min_ens_f18_ts_P14_vs_P6_20241203_15h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P6/QTI_MLP_16P_sub_min_ens_f18_ts_P6_vs_P15_20241203_15h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P15/QTI_MLP_16P_sub_min_ens_f18_ts_P15_vs_P7_20241203_15h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P7/QTI_MLP_16P_sub_min_ens_f18_ts_P7_vs_P16_20241203_15h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P16/QTI_MLP_16P_sub_min_ens_f18_ts_P16_vs_P8_20241203_15h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P8/QTI_MLP_16P_sub_min_ens_f18_ts_P8_vs_P17_20241203_15h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P17/QTI_MLP_16P_sub_min_ens_f18_ts_P17_vs_P9_20241203_15h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P9/QTI_MLP_16P_sub_min_ens_f18_ts_P9_vs_P18_20241203_15h_ep100_LR1e-03_bs512_outnorm_sched_92',\
            '/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/fit_results/QTI_MLP/Paper_Base_Run/P18/QTI_MLP_16P_sub_min_ens_f18_ts_P18_vs_P1_20241203_15h_ep100_LR1e-03_bs512_outnorm_sched_92'
            ]
target_path = [\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P1/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P10/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P2/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P11/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P3/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P12/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P4/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P13/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P5/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P14/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P6/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P15/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P7/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P16/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P8/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P17/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P9/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P18/qtip_pipe_2_XYZ/dps3_GT_nan_clmpd.mat'
             ]#
mask_path = [\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P1/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P10/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P2/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P11/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P3/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P12/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P4/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P13/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P5/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P14/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P6/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P15/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P7/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P16/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P8/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P17/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P9/manual_mask.nii.gz',\
             '/Users/olivergoedicke/Documents/Uni/PhD/MA_ML_TS/qti-preprocess/P18/manual_mask.nii.gz'
             ]#

# %% [markdown]
# Imports:

# %%
from Eval_metrics import QTI_Fit_Dataset
import matplotlib.pyplot as plt
# # plotting (open interactive plots):
# %matplotlib qt # open in extra window
# %matplotlib widget # open in notebook

# %% [markdown]
# Slice exclusion index pairs for all 18P:

# %%
# slice_ind = [[2, 23], [0, 23], [0, 22], [0, 23], [0, 23], [1, 23], [1, 23],\
#               [0, 22], [0, 23], [0, 23], [0, 22], [0, 22],\
#                 [0, 23], [1, 22], [0, 22], [1, 23], [0, 22], [0, 23]] # 0:

# slice_ind = [[2, 21] for _ in range(18)]

slice_ind = [[2, 21] for _ in range(len(pred_path))]

# %%
#-------------------------------------------------------------------------------------
# create QTI_Fit_Dataset instance:
# ds_eval = QTI_Fit_Dataset(pred_path, target_path, mask_path, out_path='/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL',\
#                            out_dir=out_dir, invar_keys = ['MD', 'FA', 'uFA', 'C_c', 'C_MD'], slice_ind=slice_ind) #'s0', 'MD', 'FA', 'uFA', 'C_c'
ds_eval = QTI_Fit_Dataset(pred_path, target_path, mask_path, out_path='/Users/olivergoedicke/Documents/Uni/PhD/Results/QTI_ML/performance_eval/QTI_MLP',\
                           out_dir=out_dir, invar_keys = ['MD', 'FA', 'uFA', 'C_c', 'C_MD'], slice_ind=slice_ind) #'s0', 'MD', 'FA', 'uFA', 'C_c'

# %%
#-------------------------------------------------------------------------------------
# perform preparations:
ds_eval.expand_mask()
ds_eval.mask_nan_vals()
ds_eval.mask_zero_vals()
# ds_eval.mask_near_zero_vals(eps=1e-2)

# %%
ds_eval.compute_SSIM(kernel_size=5)
ds_eval.SSIM_boxplot()
ds_eval.save_SSIM()

# %%
#-------------------------------------------------------------------------------------
# perform calculations (brain-wise):
ds_eval.compute_abs_diff()
ds_eval.compute_rel_diff()

ds_eval.compute_nRMSE()
ds_eval.compute_pSNR()
ds_eval.save_nRMSE()
ds_eval.save_pSNR()

# %%
#-------------------------------------------------------------------------------------
# plotting (open interactive plots):
# %matplotlib qt
# %matplotlib widget
fig1, ax1 = ds_eval.nRMSE_boxplot(save=True, out_dir='nRMSE_plots', annotate=True)
fig2, ax2 = ds_eval.pSNR_boxplot(save=True, out_dir='nRMSE_plots', annotate=True)

# %%
#-------------------------------------------------------------------------------------
# (slice-wise):
ds_eval.set_brain_wise(False)
ds_eval.set_slice_wise(True)
ds_eval.compute_nRMSE()
ds_eval.compute_pSNR()
ds_eval.save_nRMSE()
ds_eval.save_pSNR()

# %%
#-------------------------------------------------------------------------------------
# plotting (open interactive plots):
# %matplotlib qt
# %matplotlib widget
fig3, ax3 = ds_eval.nRMSE_boxplot(save=False, out_dir='nRMSE_plots', annotate=True)
fig4, ax4 = ds_eval.pSNR_boxplot(save=False, out_dir='nRMSE_plots', annotate=True)

# %%
#-------------------------------------------------------------------------------------
# (all voxel-wise):
ds_eval.set_slice_wise(False)
ds_eval.compute_nRMSE()
ds_eval.compute_pSNR()
ds_eval.save_nRMSE()
ds_eval.save_pSNR()

# %%
#-------------------------------------------------------------------------------------
# plotting (open interactive plots):
# %matplotlib qt
# %matplotlib widget
fig5, ax5 = ds_eval.nRMSE_boxplot(save=False, out_dir='nRMSE_plots', annotate=True)
fig6, ax6 = ds_eval.pSNR_boxplot(save=False, out_dir='nRMSE_plots', annotate=True)

# %%
#-------------------------------------------------------------------------------------
# plotting:
# toggle options: diff = 'rel', 'abs' (default = '' for diff)
# %matplotlib qt
# %matplotlib widget
figs, axs, sldrs_file, sldrs_slice = ds_eval.plot_diff(diff='abs', slice_ind=10, save=False, out_dir='Diff_plots')

# %%
#-------------------------------------------------------------------------------------
# plotting:
# toggle options: diff = 'rel', 'abs' (default = '' for diff)
figs2, axs2, sldrs_file2, sldrs_slice2 = ds_eval.plot_diff(diff='', slice_ind=10, save=False, out_dir='Diff_plots', vmin=-0.1, vmax=0.1)

# %%
#-------------------------------------------------------------------------------------
# saving:
# ds_eval.save_diff_2_mat(out_dir='Diff', diff='abs', sep_files=True, sep_invars=False)
# ds_eval.save_diff_2_nii(diff='abs', out_dir='Diff_nii')
# ds_eval.save_nRMSE(out_dir='nRMSE')
# ds_eval.save_pSNR(out_dir='nRMSE')

# %%
#---------------------------------------------------------------------------------------------------------------------------
# PLOTTING OF PDF MAPS FROM NII FOR FIGURES
#---------------------------------------------------------------------------------------------------------------------------
from Eval_metrics import plot_map_from_nii

#---------------------------------------------------------------------------------------------------------------------------
# NATIVE slice_ind=10
#---------------------------------------------------------------------------------------------------------------------------

# nii_path = [\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_MD.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_FA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_uFA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_c.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_full_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_MD.nii.gz'
# ]
# out_dir='/Users/olivergoedicke/Desktop/ISMRM_2024/Figures/Maps/GT/P2'
# nii_path = [\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_MD.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_FA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_uFA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_c.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_MD.nii.gz'
# ]
# out_dir='/Users/olivergoedicke/Desktop/ISMRM_2024/Figures/Maps/Fit_sub_min/P2'

# nii_path = [\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_MD.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_FA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_uFA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_C_c.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P2/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_C_MD.nii.gz'
# ]
# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/Fit_sub_min/P2'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P2/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P2_vs_P11_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P2/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P2_vs_P11_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P2/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P2_vs_P11_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P2/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P2_vs_P11_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/BENCHMARK_ABSTRACT/P2/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P2_vs_P11_20231029_12h_ep100_LR1e-03_bs512_outnorm_sched_92_C_MD_pred.nii'
# ]
# out_dir='/Users/olivergoedicke/Desktop/ISMRM_2024/Figures/Maps/MLP/P2'

#---------------------------------------------------------------------------------------------------------------------------
# HIGH RES slice_ind=7
#---------------------------------------------------------------------------------------------------------------------------

# nii_path = [\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_high_res_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_MD.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_high_res_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_FA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_high_res_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_uFA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_high_res_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_c.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_high_res_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_MD.nii.gz'
# ]
# out_dir='/Users/olivergoedicke/Desktop/ISMRM_2024/Figures/Maps/High_Res_GT'
# nii_path = [\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_MD.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_FA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_uFA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_c.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_MD.nii.gz'
# ]
# out_dir='/Users/olivergoedicke/Desktop/ISMRM_2024/Figures/Maps/High_Res_Fit'
# nii_path = [\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_MD.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_FA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_uFA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_C_c.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P20/full/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_C_MD.nii.gz'
# ]
# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Fit'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_ABSTRACT/sub/full/FINAL/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_ABSTRACT/sub/full/FINAL/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_ABSTRACT/sub/full/FINAL/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_ABSTRACT/sub/full/FINAL/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_ABSTRACT/sub/full/FINAL/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_C_MD_pred.nii'
# ]
# out_dir='/Users/olivergoedicke/Desktop/ISMRM_2024/Figures/Maps/High_Res_MLP'
# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_MLP'


for ind, path in enumerate(nii_path):
    
    if ind == 0:
        plot_map_from_nii(path, slice_ind=10, out_dir=out_dir, vmax=4.5)
    elif ind == len(nii_path)-1:
        plot_map_from_nii(path, slice_ind=10, out_dir=out_dir, vmax=0.55)
    elif ind == len(nii_path)-2:
        plot_map_from_nii(path, slice_ind=10, out_dir=out_dir, vmax=1.2)
    else:
        plot_map_from_nii(path, slice_ind=10, out_dir=out_dir)

# %%
#---------------------------------------------------------------------------------------------------------------------------
# PLOTTING OF PDF MAPS FROM NII FOR FIGURES (HIGH RES TEST ACQ)
#---------------------------------------------------------------------------------------------------------------------------
from Eval_metrics import plot_map_from_nii
# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Scan/2_5mm'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/2mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Scan/2_0mm'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_9mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_9mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_9mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_9mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_9mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Scan/1_9mm'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_8mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_8mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_8mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_8mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_8mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Scan/1_8mm'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_7mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_7mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_7mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_7mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_7mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Scan/1_7mm'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_Res_scans/1_5mm/QTI_MLP_14P_BM_High_Res_sub_min_pp_ens_f1_ts__vs_P1_20231020_13h_ep100_LR1e-03_bs512_outnorm_sched_92_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Scan/1_5mm'


for ind, path in enumerate(nii_path):
    
    if ind == 0:
        plot_map_from_nii(path, slice_ind=8, out_dir=out_dir, vmax=4.5)
    elif ind == len(nii_path)-1:
        plot_map_from_nii(path, slice_ind=8, out_dir=out_dir, vmax=0.55)
    elif ind == len(nii_path)-2:
        plot_map_from_nii(path, slice_ind=8, out_dir=out_dir, vmax=1.2)
    else:
        plot_map_from_nii(path, slice_ind=8, out_dir=out_dir)

# %%
#---------------------------------------------------------------------------------------------------------------------------
# PLOTTING OF PDF MAPS FROM NII FOR FIGURES (PATIENT ACQ)
#---------------------------------------------------------------------------------------------------------------------------
from Eval_metrics import plot_map_from_nii
# nii_path = [\
#             '/Volumes/Maxtor/ML_TS/Pt_2/high_res/qtip_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_MD.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/Pt_2/high_res/qtip_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_FA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/Pt_2/high_res/qtip_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_uFA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/Pt_2/high_res/qtip_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_c.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/Pt_2/high_res/qtip_pipe_2/0_nii_pdf_maps/dps3/dtd_covariance_C_MD.nii.gz'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/Patient_Scans/1_7mm/Fit'


# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/full_mask/high_res/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/full_mask/high_res/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/full_mask/high_res/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/full_mask/high_res/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/full_mask/high_res/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_C_MD_pred.nii',\
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/Patient_Scans/1_7mm/MLP'

nii_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/native/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_MD_pred.nii',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/native/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_FA_pred.nii',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/native/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_uFA_pred.nii',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/native/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_C_c_pred.nii',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/Patient_measurements/Pt_2/native/QTI_MLP_16P_bm_ABSTRACT_sub_min_case_m_ens_f18_ts_P18_vs_P1_20231029_14h_ep100_LR1e-03_bs512_outnorm_sched_92_avg_C_MD_pred.nii',\
]

out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/Patient_Scans/2_5mm/MLP'


for ind, path in enumerate(nii_path):
    
    if ind == 0:
        plot_map_from_nii(path, slice_ind=16, out_dir=out_dir, vmax=4.5)
    elif ind == len(nii_path)-1:
        plot_map_from_nii(path, slice_ind=16, out_dir=out_dir, vmax=0.55)
    elif ind == len(nii_path)-2:
        plot_map_from_nii(path, slice_ind=16, out_dir=out_dir, vmax=1.2)
    else:
        plot_map_from_nii(path, slice_ind=16, out_dir=out_dir)

# %%
#---------------------------------------------------------------------------------------------------------------------------
# PLOTTING OF PDF MAPS FROM NII FOR FIGURES (HIGH RES TEST SIM)
#---------------------------------------------------------------------------------------------------------------------------
from Eval_metrics import plot_map_from_nii

# fit 2.5 mm:

# nii_path = [\
#             '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_MD.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_FA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_uFA.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_C_c.nii.gz',\
#             '/Volumes/Maxtor/ML_TS/P11/qtip_sub_min_pipe_2_b0_incl/0_nii_pdf_maps/dps3/dtd_covariance_C_MD.nii.gz'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Sim/2_5mm_fit'

# measured 2.0 mm:

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/measured/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/measured/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/measured/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/measured/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/measured/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Sim/2_0mm_measured'


# BM 2.5 mm:
# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/bm/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/bm/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/bm/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/bm/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/bm/P11/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Sim/2_5mm'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Sim/2_2'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_0/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_0/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_0/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_0/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/2_0/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Sim/2_0'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_8/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_8/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_8/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_8/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_8/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Sim/1_8'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_6/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_6/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_6/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_6/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_6/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Sim/1_6'

# nii_path = [\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_4/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_MD_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_4/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_FA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_4/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_uFA_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_4/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_c_pred.nii',\
#             '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_4/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_MD_pred.nii'
# ]

# out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Sim/1_4'

nii_path = [\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_MD_pred.nii',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_FA_pred.nii',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_uFA_pred.nii',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_c_pred.nii',\
            '/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/Results/fit_results/QTI_MLP/High_res_test_sim/SNR/simulation/1_2/QTI_MLP_14P_Prot_Vgl_sub_min_pp_ens_f18_ts_P11_vs_P3P12P4_20231015_23h_ep50_LR1e-04_bs512_outnorm_C_MD_pred.nii'
]

out_dir='/Users/olivergoedicke/Documents/Uni/Master_Ph/MA/MATex/Figures/param_maps/High_Res_Test_Sim/1_2'

for ind, path in enumerate(nii_path):
    
    if ind == 0:
        plot_map_from_nii(path, slice_ind=10, out_dir=out_dir, vmax=4.5)
    elif ind == len(nii_path)-1:
        plot_map_from_nii(path, slice_ind=10, out_dir=out_dir, vmax=0.55)
    elif ind == len(nii_path)-2:
        plot_map_from_nii(path, slice_ind=10, out_dir=out_dir, vmax=1.2)
    else:
        plot_map_from_nii(path, slice_ind=10, out_dir=out_dir)

# %%
from nRMSE_figure import nRMSE_comp_plot

# path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/BENCHMARK_ABSTRACT/P_eval_fit_sub_min/nRMSE_bw.mat'
# path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/BENCHMARK_ABSTRACT/ABSTRACT_High_Res_Fit_sub_min/nRMSE_vw.mat'

# path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/P_eval_fit_sub_min_b0_incl_common_clamp/nRMSE_bw.mat'
path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/THESIS_High_Res_fit_sub_min_b0_incl/nRMSE_bw.mat'

# path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/BENCHMARK_ABSTRACT/P_eval_BENCHMARK_ABSTRACT_sub_min/nRMSE_bw.mat'
# path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/BENCHMARK_ABSTRACT/ABSTRACT_High_Res_MLP_sub_min_clmpd/nRMSE_vw.mat'

# path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/P_eval_BENCHMARK_ABSTRACT_sub_min/nRMSE_bw.mat'
path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/THESIS_High_Res_MLP_sub_min/nRMSE_bw.mat'

fig, ax = nRMSE_comp_plot(path_1, path_2, mean_vs_med=True)

# %%
from pSNR_figure import pSNR_comp_plot

# path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/BENCHMARK_ABSTRACT/P_eval_fit_sub_min/pSNR_bw.mat'
# path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/BENCHMARK_ABSTRACT/ABSTRACT_High_Res_Fit_sub_min/pSNR_vw.mat'

# path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/P_eval_fit_sub_min_b0_incl_common_clamp/pSNR_bw.mat'
path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/THESIS_High_Res_fit_sub_min_b0_incl/pSNR_bw.mat'

# path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/BENCHMARK_ABSTRACT/P_eval_BENCHMARK_ABSTRACT_sub_min/pSNR_bw.mat'
# path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/BENCHMARK_ABSTRACT/ABSTRACT_High_Res_MLP_sub_min_clmpd/pSNR_vw.mat'

# path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/P_eval_BENCHMARK_ABSTRACT_sub_min/pSNR_bw.mat'
path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/THESIS_High_Res_MLP_sub_min/pSNR_bw.mat'

fig, ax = pSNR_comp_plot(path_1, path_2, mean_vs_med=True)

# %%
from SSIM_figure import SSIM_comp_plot

# path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/P_eval_fit_sub_min_b0_incl_common_clamp/SSIM_bw.mat'
path_1 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/THESIS_High_Res_fit_sub_min_b0_incl/SSIM_bw.mat'

# path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/P_eval_BENCHMARK_ABSTRACT_sub_min/SSIM_bw.mat'
path_2 = '/Users/olivergoedicke/Desktop/ML_Dokumentation/THESIS_FINAL/THESIS_High_Res_MLP_sub_min/SSIM_bw.mat'

fig, ax = SSIM_comp_plot(path_1, path_2, mean_vs_med=True)

# %%
from numpy.random import rand
import matplotlib.pyplot as plt
a = rand(500,1)
bp = plt.boxplot(a)
wh = bp['caps']

# %%
import torch
a = [5,6,7,3,6]
b = torch.tensor(a)
c = b.detach().cpu().numpy()

# %%
from QTI_MLP import QTI_MLP
model = QTI_MLP(54, 5, False, False)

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
print(count_parameters(model))
